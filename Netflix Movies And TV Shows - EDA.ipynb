# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load CSV file

# %%
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Overview on the Dataset

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # Analysis

# %% [markdown]
# Droping Duplicates

# %%
df.duplicated().sum()
df.drop_duplicates()
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Droping unnecessary column

# %%
df.drop(['description'],axis=1,inplace=True)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Handling Missing values

# %%
df['director'].fillna('unvaliable',inplace=True)
df['cast'].fillna('unvaliable',inplace=True)
df['country']=df['country'].fillna(df['country'].mode()[0])
df['date_added']=df['date_added'].ffill()
df['rating']=df['rating'].fillna(df['rating'].mode()[0])
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water       unvaliable
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans       unvaliable
# 4      s5  TV Show           Kota Factory       unvaliable
#
#                                                 cast        country  \
# 0                                         unvaliable  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                         unvaliable  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# Changing Data Type : Int to Date

# %%
df['date_added'] = pd.to_datetime(df['date_added'].str.strip(),
                                  format='%B %d, %Y', errors='coerce')

# %%
df['date_added']
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR',
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
valid_ratings = ['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
       'TV-G', 'G', 'NC-17', 'NR',
       'TV-Y7-FV', 'UR']

df['rating'] = df['rating'].where(df['rating'].isin(valid_ratings))

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water       unvaliable
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans       unvaliable
# 4         s5  TV Show           Kota Factory       unvaliable
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb       unvaliable
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                            unvaliable  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', nan, 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# Renaming the columns

# %%
df.rename(columns = {'listed_in' : 'categories'}, inplace=True)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water       unvaliable
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans       unvaliable
# 4      s5  TV Show           Kota Factory       unvaliable
#
#                                                 cast        country  \
# 0                                         unvaliable  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                         unvaliable  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df['duration_min'] = df['duration'].apply(
    lambda x: int(str(x).split()[0]) if isinstance(x, str) and 'min' in x else 0
)

# %%
df['duration_season'] = df['duration'].apply(
    lambda x: int(str(x).split()[0]) if isinstance(x, str) and 'Seasons' in x else 0
)

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water       unvaliable
#
#                                                 cast        country  \
# 0                                         unvaliable  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                         categories  duration_min  \
# 0                                    Documentaries            90
# 1  International TV Shows, TV Dramas, TV Mysteries             0
#
#    duration_season
# 0                0
# 1                2

# %% [markdown]
# Actors and the Movies they casted

# %%
filterd_actor=df[df['cast']!= 'unvaliable']
top_actor= filterd_actor['cast'].value_counts().head(10).to_frame()
top_actor
# Out:
#                                                     cast
# David Attenborough                                    19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jign...    14
# Samuel West                                           10
# Jeff Dunham                                            7
# David Spade, London Hughes, Fortune Feimster           6
# Kevin Hart                                             6
# Craig Sechler                                          6
# Michela Luci, Jamie Watson, Eric Peterson, Anna...     6
# Bill Burr                                              5
# Iliza Shlesinger                                       5

# %% [markdown]
# Movies w.r.t country

# %%
Country= df['country'].value_counts().to_frame()
Country
# Out:
#                                         country
# United States                              3649
# India                                       972
# United Kingdom                              419
# Japan                                       245
# South Korea                                 199
# ...                                         ...
# Romania, Bulgaria, Hungary                    1
# Uruguay, Guatemala                            1
# France, Senegal, Belgium                      1
# Mexico, United States, Spain, Colombia        1
# United Arab Emirates, Jordan                  1
#
# [748 rows x 1 columns]

# %% [markdown]
# Rating count

# %%
Rating= df['rating'].value_counts().to_frame()
Rating
# Out:
#           rating
# TV-MA       3211
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3

# %% [markdown]
# Lets get the month and Year, When the movie is added on Netflix

# %%
df['month'] = df['date_added'].dt.month
df['year'] = df['date_added'].dt.year

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water       unvaliable
#
#                                                 cast        country  \
# 0                                         unvaliable  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                         categories  duration_min  \
# 0                                    Documentaries            90
# 1  International TV Shows, TV Dramas, TV Mysteries             0
#
#    duration_season  month  year
# 0                0      9  2021
# 1                2      9  2021

# %%
pd.crosstab(df['country'],df['type'])
# Out:
# type                                                Movie  TV Show
# country
# , France, Algeria                                       1        0
# , South Korea                                           0        1
# Argentina                                              38       18
# Argentina, Brazil, France, Poland, Germany, Den...      1        0
# Argentina, Chile                                        2        0
# ...                                                   ...      ...
# Venezuela                                               1        0
# Venezuela, Colombia                                     1        0
# Vietnam                                                 7        0
# West Germany                                            1        0
# Zimbabwe                                                1        0
#
# [748 rows x 2 columns]

# %%
pd.crosstab(df['rating'],df['type'])
# Out:
# type      Movie  TV Show
# rating
# G            41        0
# NC-17         3        0
# NR           75        5
# PG          287        0
# PG-13       490        0
# R           797        2
# TV-14      1427      733
# TV-G        126       94
# TV-MA      2064     1147
# TV-PG       540      323
# TV-Y        131      176
# TV-Y7       139      195
# TV-Y7-FV      5        1
# UR            3        0

# %%
Gouped_Type=df.groupby(['date_added','type']).size().unstack()
Gouped_Type
# Out:
# type        Movie  TV Show
# date_added
# 2008-01-01    1.0      NaN
# 2008-02-04    NaN      1.0
# 2009-05-05    1.0      NaN
# 2009-11-18    1.0      NaN
# 2010-11-01    1.0      NaN
# ...           ...      ...
# 2021-09-21    4.0      1.0
# 2021-09-22    3.0      6.0
# 2021-09-23    1.0      1.0
# 2021-09-24    3.0      7.0
# 2021-09-25    1.0      NaN
#
# [1714 rows x 2 columns]

# %%
df.groupby("categories")["duration_min"].mean().sort_values(ascending=False)
# Out:
# categories
# Classic Movies, Music & Musicals                               173.000000
# Action & Adventure, Cult Movies, Dramas                        172.000000
# Action & Adventure, Classic Movies, International Movies       166.000000
# Cult Movies, Dramas, Thrillers                                 158.000000
# Classic Movies, Dramas, Romantic Movies                        153.666667
#                                                                   ...
# British TV Shows, Crime TV Shows, Docuseries                     0.000000
# British TV Shows, Classic & Cult TV, TV Comedies                 0.000000
# British TV Shows, Classic & Cult TV, Kids' TV                    0.000000
# British TV Shows, Classic & Cult TV, International TV Shows      0.000000
# Crime TV Shows, TV Action & Adventure, TV Sci-Fi & Fantasy       0.000000
# Name: duration_min, Length: 514, dtype: float64

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water       unvaliable
#
#                                                 cast        country  \
# 0                                         unvaliable  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                         categories  duration_min  \
# 0                                    Documentaries            90
# 1  International TV Shows, TV Dramas, TV Mysteries             0
#
#    duration_season  month  year
# 0                0      9  2021
# 1                2      9  2021

# %% [markdown]
# # Save To CSV

# %%
df.to_csv("netflix.csv",index=False,encoding="utf-8")

# %% [markdown]
# # Visualization

# %%
# Plot the distribution of first 10 countries 
plt.figure(figsize=(12, 6))
sns.countplot(x='country', data=df, order=df['country'].value_counts().head(10).index)
plt.xticks(rotation=90)
plt.title('Distribution of Countries')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %%
# Plot the trend of movies and shows over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='month', hue='type', data=df)
plt.title('Trend of Movies and Shows Over Time')
plt.xlabel('Year')
plt.ylabel('Month')
plt.show()

# %%
# Plot the average duration by category (Top 10)
plt.figure(figsize=(12, 6))
df.groupby("categories")["duration_min"].mean().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title('Average Duration by Category (Top 10)')
plt.xlabel('Category')
plt.ylabel('Average Duration (minutes)')
plt.xticks(rotation=90)
plt.show()
